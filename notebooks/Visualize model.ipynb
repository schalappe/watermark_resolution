# %% [markdown]
# ## Import

# %%
import sys
sys.path.insert(
    0,
    "/Users/schalappe/Documents/Lab/Engineer/Projects/watermark_resolution"
)

# %%
import tensorflow as tf
from src.model import WaterMark, ExtractWaterMark

# %% [markdown]
# ## Models

# %% [markdown]
# ### Watermaker

# %%
model = WaterMark.build(
    image_dims=(64, 64, 1), 
    mark_dims=(4, 4, 1)
)
# Out:
# Metal device set to: Apple M1 Pro
# 2022-02-19 17:40:42.331110: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2022-02-19 17:40:42.331220: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %%
tf.keras.utils.plot_model(model, to_file="watermark.png", show_shapes=True)

# %% [markdown]
# ### Extraction of watermark

# %%
model = ExtractWaterMark.build(
    mark_dims=(4, 4, 1)
)

# %%
tf.keras.utils.plot_model(model, to_file="extract_watermark.png", show_shapes=True)
