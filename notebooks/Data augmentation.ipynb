# %% [markdown]
# ## Import

# %%
import matplotlib.pyplot as plt
import tensorflow as tf
import numpy as np
import imgaug.augmenters as iaa

# %%
from src.processors import (
    load_image,
    random_rotate,
    random_dropout,
    random_average_blur,
    random_median_blur,
    random_gaussian_noise,
    random_salt_pepper,
    random_jpeg_quality,
    random_augmentation
)

# %% [markdown]
# ### Plot

# %%
image = load_image("/Users/schalappe/Documents/Lab/Engineer/Projects/watermark_resolution/data/Testing/2.png")
# Out:
# Metal device set to: Apple M1 Pro
# 2022-03-18 21:57:40.441258: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2022-03-18 21:57:40.441406: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# 2022-03-18 21:57:40.451876: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 2022-03-18 21:57:40.452027: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.

# %%
plt.imshow(image, cmap="gray")

# %%
img_batch = tf.reshape(image, shape=(-1, *image.shape))

# %% [markdown]
# ### Geometric

# %%
aug = iaa.Sequential([
    iaa.CropAndPad(percent=-0.25),
    iaa.CropAndPad(percent=0.25)
])
res_image = aug(image=image.numpy())

# %%
plt.imshow(res_image, cmap="gray")

# %% [markdown]
# #### Rotation

# %%
rotate_image = random_rotate(image)
# Out:
# 2022-03-18 21:57:40.633212: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-03-18 21:57:40.652248: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-03-18 21:57:40.731136: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.

# %%
plt.imshow(rotate_image, cmap="gray")

# %% [markdown]
# #### Dropout

# %%
dropout_image = random_dropout(image)

# %%
plt.imshow(dropout_image, cmap="gray")

# %% [markdown]
# ### Pixel

# %% [markdown]
# #### Average blur

# %%
blur_image = random_average_blur(image)

# %%
plt.imshow(blur_image, cmap="gray")

# %% [markdown]
# #### Median blur

# %%
blur_image = random_median_blur(image)

# %%
plt.imshow(blur_image, cmap="gray")

# %% [markdown]
# #### Gaussian noise

# %%
noise_image = random_gaussian_noise(image)

# %%
plt.imshow(noise_image, cmap="gray")

# %% [markdown]
# #### Salt and pepper

# %%
noise_image = random_salt_pepper(image)

# %%
plt.imshow(noise_image, cmap="gray")

# %% [markdown]
# #### JPEG Quality

# %%
bad_image = random_jpeg_quality(image)

# %%
plt.imshow(bad_image, cmap="gray")

# %% [markdown]
# ### Random

# %%
aug_image = random_augmentation(image)

# %%
plt.imshow(aug_image, cmap="gray")
